# %% [markdown]
# <p><img alt="Colaboratory logo" height="55px" src="https://www.gstatic.com/devrel-devsite/prod/vf0396724755d04dbab75050e6812ced8fb2ab11d424163deba5826536b4b1964/tensorflow/images/lockup.svg" align="left" hspace="10px" vspace="0px"></p>
#
# <p><img alt="Colaboratory logo" height="55px" src="https://keras.io/img/logo.png" align="left" hspace="10px" vspace="0px"></p>

# %% [markdown]
# Table of contents:
# - [Tensorflow & Keras](#TF-KS)
# - [Dataset](#Dataset)
# - [Training](#Training)

# %% [markdown]
# <a name="TF-KS"></a>
# ## **Tensorflow and Keras**

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %% [markdown]
# <a name="Dataset"></a>
# ## **Dataset**

# %% [markdown]
# > Used Cars
# <p><img alt="Colaboratory logo" height="55px" src="https://upload.wikimedia.org/wikipedia/commons/thumb/9/99/GAZ-24_Volga.svg/640px-GAZ-24_Volga.svg.png" align="left" hspace="10px" vspace="0px"></p>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd
data = pd.read_csv("/content/drive/My Drive/Python Course/ann_used_cars.csv", usecols=["mileage", 'year', "price"])
data.head()
# Out:
#    year  price  mileage
# 0  2011  21992     7413
# 1  2011  20995    10926
# 2  2011  19995     7351
# 3  2011  17809    11613
# 4  2012  17500     8367

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data[['mileage','year']], data['price'], test_size=0.3, random_state=42)

# %% [markdown]
# <a name="Training"></a>
# ## **Training**

# %% [markdown]
# <a href="https://ibb.co/gV2rqgz"><img src="https://i.ibb.co/FVrhZ7g/bias-weights2.png" alt="bias-weights2" border="0"></a>

# %%
from tensorflow.keras.layers import Dense, Input, InputLayer

model = tf.keras.Sequential()
model.add(InputLayer(input_shape=2))
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error')

# %%
model.fit(X_train, y_train, epochs=100, verbose=True, validation_split=0.1)
print("Finished training the model")
# Out:
# Epoch 1/100
# 3/3 [==============================] - 5s 86ms/step - loss: 1004517312.0000 - val_loss: 857965568.0000
# Epoch 2/100
# 3/3 [==============================] - 0s 15ms/step - loss: 984098368.0000 - val_loss: 844732800.0000
# Epoch 3/100
# 3/3 [==============================] - 0s 19ms/step - loss: 969785792.0000 - val_loss: 833497152.0000
# Epoch 4/100
# 3/3 [==============================] - 0s 15ms/step - loss: 957397440.0000 - val_loss: 823565248.0000
# Epoch 5/100
# 3/3 [==============================] - 0s 16ms/step - loss: 946328192.0000 - val_loss: 814385344.0000
# Epoch 6/100
# 3/3 [==============================] - 0s 15ms/step - loss: 935838400.0000 - val_loss: 805368064.0000
# Epoch 7/100
# 3/3 [==============================] - 0s 25ms/step - loss: 925752832.0000 - val_loss: 796982016.0000
# Epoch 8/100
# 3/3 [==============================] - 0s 16ms/step - loss: 916065856.0000 - val_loss: 788638272.0000
# Epoch 9/100
# 3/3 [==============================] - 0s 15ms/step - loss: 906472320.0000 - val_loss: 780377664.0000
# Epoch 10/100
# 3/3 [==============================] - 0s 15ms/step - loss: 897145920.0000 - val_loss: 772385984.0000
# Epoch 11/100
# 3/3 [==============================] - 0s 15ms/step - loss: 887823488.0000 - val_loss: 764303104.0000
# Epoch 12/100
# 3/3 [==============================] - 0s 15ms/step - loss: 878542912.0000 - val_loss: 756272192.0000
# Epoch 13/100
# 3/3 [==============================] - 0s 16ms/step - loss: 869320064.0000 - val_loss: 748310464.0000
# Epoch 14/100
# 3/3 [==============================] - 0s 16ms/step - loss: 860264000.0000 - val_loss: 740584320.0000
# Epoch 15/100
# 3/3 [==============================] - 0s 16ms/step - loss: 851304448.0000 - val_loss: 732746688.0000
# Epoch 16/100
# 3/3 [==============================] - 0s 15ms/step - loss: 842334400.0000 - val_loss: 725026176.0000
# Epoch 17/100
# 3/3 [==============================] - 0s 16ms/step - loss: 833586048.0000 - val_loss: 717512064.0000
# Epoch 18/100
# 3/3 [==============================] - 0s
0000
# Epoch 66/100
# 3/3 [==============================] - 0s 15ms/step - loss: 464955904.0000 - val_loss: 399626112.0000
# Epoch 67/100
# 3/3 [==============================] - 0s 15ms/step - loss: 458697024.0000 - val_loss: 394238240.0000
# Epoch 68/100
# 3/3 [==============================] - 0s 15ms/step - loss: 452470752.0000 - val_loss: 388839584.0000
# Epoch 69/100
# 3/3 [==============================] - 0s 15ms/step - loss: 446322688.0000 - val_loss: 383619136.0000
# Epoch 70/100
# 3/3 [==============================] - 0s 18ms/step - loss: 440232672.0000 - val_loss: 378413088.0000
# Epoch 71/100
# 3/3 [==============================] - 0s 15ms/step - loss: 434184288.0000 - val_loss: 373176032.0000
# Epoch 72/100
# 3/3 [==============================] - 0s 15ms/step - loss: 428150688.0000 - val_loss: 368026592.0000
# Epoch 73/100
# 3/3 [==============================] - 0s 15ms/step - loss: 422179168.0000 - val_loss: 362867008.0000
# Epoch 74/100
# 3/3 [==============================] - 0s 21ms/step - loss: 416251296.0000 - val_loss: 357832512.0000
# Epoch 75/100
# 3/3 [==============================] - 0s 15ms/step - loss: 410433568.0000 - val_loss: 352832736.0000
# Epoch 76/100
# 3/3 [==============================] - 0s 14ms/step - loss: 404627296.0000 - val_loss: 347821536.0000
# Epoch 77/100
# 3/3 [==============================] - 0s 16ms/step - loss: 398841280.0000 - val_loss: 342890496.0000
# Epoch 78/100
# 3/3 [==============================] - 0s 16ms/step - loss: 393180736.0000 - val_loss: 338061312.0000
# Epoch 79/100
# 3/3 [==============================] - 0s 16ms/step - loss: 387537280.0000 - val_loss: 333189312.0000
# Epoch 80/100
# 3/3 [==============================] - 0s 16ms/step - loss: 381947552.0000 - val_loss: 328403296.0000
# Epoch 81/100
# 3/3 [==============================] - 0s 24ms/step - loss: 376370336.0000 - val_loss: 323631584.0000
# Epoch 82/100
# 3/3 [==============================] - 0s 17ms/step - loss: 370849664.0000 - val_loss: 318907456.0000
# Epoch 83/100
# 3/3 [==============================] - 0s 16ms/step - loss: 365382112.0000 - val_loss: 314210688.0000
# Epoch 84/100
# 3/3 [==============================] - 0s 16ms/step - loss: 360010208.0000 - val_loss: 309659680.0000
# Epoch 85/100
# 3/3 [==============================] - 0s 24ms/step - loss: 354670272.0000 - val_loss: 305053568.0000
# Epoch 86/100
# 3/3 [==============================] - 0s 15ms/step - loss: 349415648.0000 - val_loss: 300580800.0000
# Epoch 87/100
# 3/3 [==============================] - 0s 16ms/step - loss: 344189856.0000 - val_loss: 296112928.0000
# Epoch 88/100
# 3/3 [==============================] - 0s 15ms/step - loss: 338983584.0000 - val_loss: 291643232.0000
# Epoch 89/100
# 3/3 [==============================] - 0s 15ms/step - loss: 333844480.0000 - val_loss: 287260320.0000
# Epoch 90/100
# 3/3 [==============================] - 0s 19ms/step - loss: 328715488.0000 - val_loss: 282865248.0000
# Epoch 91/100
# 3/3 [==============================] - 0s 16ms/step - loss: 323690816.0000 - val_loss: 278616864.0000
# Epoch 92/100
# 3/3 [==============================] - 0s 15ms/step - loss: 318759776.0000 - val_loss: 274400224.0000
# Epoch 93/100
# 3/3 [==============================] - 0s 14ms/step - loss: 313856032.0000 - val_loss: 270199328.0000
# Epoch 94/100
# 3/3 [==============================] - 0s 17ms/step - loss: 308954848.0000 - val_loss: 265999600.0000
# Epoch 95/100
# 3/3 [==============================] - 0s 15ms/step - loss: 304061760.0000 - val_loss: 261818880.0000
# Epoch 96/100
# 3/3 [==============================] - 0s 17ms/step - loss: 299240288.0000 - val_loss: 257741712.0000
# Epoch 97/100
# 3/3 [==============================] - 0s 20ms/step - loss: 294492544.0000 - val_loss: 253681248.0000
# Epoch 98/100
# 3/3 [==============================] - 0s 16ms/step - loss: 289803680.0000 - val_loss: 249688624.0000
# Epoch 99/100
# 3/3 [==============================] - 0s 17ms/step - loss: 285132256.0000 - val_loss: 245677424.0000
# Epoch 100/100
# 3/3 [==============================] - 0s 15ms/step - loss: 280546336.0000 - val_loss: 241822784.0000
# Finished training the model

# %% [markdown]
# <a href="https://ibb.co/gV2rqgz"><img src="https://i.ibb.co/FVrhZ7g/bias-weights2.png" alt="bias-weights2" border="0"></a>

# %%
# Weight
model.layers[0].get_weights()[0]
# Out:
# array([[-0.09595852],
#        [ 0.36906773]], dtype=float32)

# %%
# Bias
model.layers[0].get_weights()[1]
# Out:
# array([0.30374867], dtype=float32)

# %%
y_pred = model.predict(X_test)
print('Predicted Values', y_pred[0:5].round().tolist())
print('Actual Values', y_test[0:5].tolist())
# Out:
# 2/2 [==============================] - 0s 3ms/step
# Predicted Values [[-1900.0], [-377.0], [-6670.0], [-2569.0], [-5405.0]]
# Actual Values [13663, 15992, 10815, 13383, 13425]

# %%
# Accuracy (Root Mean Squared Error)
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 16627.824884890568
